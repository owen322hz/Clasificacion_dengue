# %%
import pandas as pd

df = pd.read_csv('/content/datos_abiertos_vigilancia_dengue_2000_2023.csv', engine='python', encoding='latin1')
display(df.head())
# Out:
#   departamento      provincia                distrito  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN
#
#                     enfermedad     ano  semana diagnostic tipo_dx  diresa  \
# 0  DENGUE SIN SIGNOS DE ALARMA  2000.0    47.0      A97.0       P    10.0
# 1  DENGUE SIN SIGNOS DE ALARMA  2000.0    40.0      A97.0       P    10.0
# 2  DENGUE SIN SIGNOS DE ALARMA  2000.0    48.0      A97.0       C    10.0
# 3  DENGUE SIN SIGNOS DE ALARMA  2000.0    37.0      A97.0       P    10.0
# 4  DENGUE SIN SIGNOS DE ALARMA  2000.0    42.0      A97.0       C    10.0
#
#      ubigeo  edad tipo_edad sexo
# 0  100605.0   9.0         A    M
# 1  100605.0  18.0         A    F
# 2  100604.0  32.0         A    F
# 3  100604.0  40.0         A    F
# 4  100606.0  16.0         A    M

# %%
# Drop the 'diagnostic' column
df = df.drop('enfermedad', axis=1)

# Drop rows with any missing values
df = df.dropna()

# Display the first few rows of the modified DataFrame
display(df.head())
# Out:
#   departamento      provincia                distrito     ano  semana  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    47.0
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    40.0
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    48.0
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    37.0
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000.0    42.0
#
#   diagnostic tipo_dx  diresa    ubigeo  edad tipo_edad sexo
# 0      A97.0       P    10.0  100605.0   9.0         A    M
# 1      A97.0       P    10.0  100605.0  18.0         A    F
# 2      A97.0       C    10.0  100604.0  32.0         A    F
# 3      A97.0       P    10.0  100604.0  40.0         A    F
# 4      A97.0       C    10.0  100606.0  16.0         A    M

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174147 entries, 0 to 174146
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   departamento  174147 non-null  object
#  1   provincia     174147 non-null  object
#  2   distrito      174147 non-null  object
#  3   ano           174147 non-null  float64
#  4   semana        174147 non-null  float64
#  5   diagnostic    174147 non-null  object
#  6   tipo_dx       174147 non-null  object
#  7   diresa        174147 non-null  float64
#  8   ubigeo        174147 non-null  float64
#  9   edad          174147 non-null  float64
#  10  tipo_edad     174147 non-null  object
#  11  sexo          174147 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 17.3+ MB
# None

# %%
display(df.isnull().sum())
# Out:
# departamento    0
# provincia       0
# distrito        0
# ano             0
# semana          0
# diagnostic      0
# tipo_dx         0
# diresa          0
# ubigeo          0
# edad            0
# tipo_edad       0
# sexo            0
# dtype: int64

# %%
df.head()
# Out:
#   departamento      provincia                distrito     ano  semana  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    47.0
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    40.0
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    48.0
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    37.0
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000.0    42.0
#
#   diagnostic tipo_dx  diresa    ubigeo  edad tipo_edad sexo
# 0      A97.0       P    10.0  100605.0   9.0         A    M
# 1      A97.0       P    10.0  100605.0  18.0         A    F
# 2      A97.0       C    10.0  100604.0  32.0         A    F
# 3      A97.0       P    10.0  100604.0  40.0         A    F
# 4      A97.0       C    10.0  100606.0  16.0         A    M

# %% [markdown]
# # Revisar la distribucion de edad

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a histogram of the 'edad' column
sns.histplot(data=df, x='edad')
plt.title("Distribution of Age")
plt.show()

# Create a box plot of the 'edad' column
sns.boxplot(data=df, x='edad')
plt.title("Box Plot of Age")
plt.show()

# %% [markdown]
# # eliminando la columna y del df  y asignando en Y

# %%
y = df['diagnostic']
df = df.drop('diagnostic', axis=1)

print("First 5 rows of the DataFrame after dropping 'enfermedad':")
display(df.head())

print("\nFirst 5 values of the 'enfermedad' column (y):")
display(y.head())
# Out:
# First 5 rows of the DataFrame after dropping 'enfermedad':
#   departamento      provincia                distrito     ano  semana tipo_dx  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    47.0       P
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO  2000.0    40.0       P
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    48.0       C
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000.0    37.0       P
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000.0    42.0       C
#
#    diresa    ubigeo  edad tipo_edad sexo
# 0    10.0  100605.0   9.0         A    M
# 1    10.0  100605.0  18.0         A    F
# 2    10.0  100604.0  32.0         A    F
# 3    10.0  100604.0  40.0         A    F
# 4    10.0  100606.0  16.0         A    M
# First 5 values of the 'enfermedad' column (y):
# 0    A97.0
# 1    A97.0
# 2    A97.0
# 3    A97.0
# 4    A97.0
# Name: diagnostic, dtype: object

# %% [markdown]
# # division de 60%  entrenamiento, 20% validación y 20% prueba

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and the rest (test + validation)
X_train, X_rest, y_train, y_rest = train_test_split(df, y, test_size=0.4, random_state=42, stratify=y)

# Split the rest into test and validation sets
X_test, X_val, y_test, y_val = train_test_split(X_rest, y_rest, test_size=0.5, random_state=42, stratify=y_rest)

# Display the shapes of the resulting sets
print("Shape of training set (X_train, y_train):", X_train.shape, y_train.shape)
print("Shape of testing set (X_test, y_test):", X_test.shape, y_test.shape)
print("Shape of validation set (X_val, y_val):", X_val.shape, y_val.shape)
# Out:
# Shape of training set (X_train, y_train): (104488, 11) (104488,)
# Shape of testing set (X_test, y_test): (34829, 11) (34829,)
# Shape of validation set (X_val, y_val): (34830, 11) (34830,)

# %% [markdown]
# # la proporcion de desvalance

# %%
print("Distribution of 'enfermedad' in y_train:")
display(y_train.value_counts(normalize=True))

print("\nDistribution of 'enfermedad' in y_test:")
display(y_test.value_counts(normalize=True))

print("\nDistribution of 'enfermedad' in y_val:")
display(y_val.value_counts(normalize=True))
# Out:
# Distribution of 'enfermedad' in y_train:
# diagnostic
# A97.0    0.932231
# A97.1    0.062773
# A97.2    0.004996
# Name: proportion, dtype: float64
# Distribution of 'enfermedad' in y_test:
# diagnostic
# A97.0    0.932240
# A97.1    0.062764
# A97.2    0.004996
# Name: proportion, dtype: float64
# Distribution of 'enfermedad' in y_val:
# diagnostic
# A97.0    0.932242
# A97.1    0.062762
# A97.2    0.004996
# Name: proportion, dtype: float64

# %%
# Out:
# diagnostic
# A97.0    97407
# A97.1     6559
# A97.2      522
# Name: count, dtype: int64

# %% [markdown]
# # Aplicando la codificacion "categorical encoddding"

# %%
# Identify categorical columns
categorical_cols = X_train.select_dtypes(include=['object']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index(['departamento', 'provincia', 'distrito', 'tipo_dx', 'tipo_edad',
#        'sexo'],
#       dtype='object')

# %%
import category_encoders as ce

# Initialize Target Encoder
# We will use the training data to fit the encoder
target_encoder = ce.TargetEncoder(cols=categorical_cols)
target_encoder.fit(X_train, y_train)

# Transform the training, test, and validation sets
X_train_encoded = target_encoder.transform(X_train)
X_test_encoded = target_encoder.transform(X_test)
X_val_encoded = target_encoder.transform(X_val)

# Display the first few rows of the encoded training set
print("First 5 rows of the target-encoded training set:")
display(X_train_encoded.head())
# Out:
# First 5 rows of the target-encoded training set:
#         departamento  provincia  distrito     ano  semana   tipo_dx  diresa  \
# 63247       0.110619   0.109709  0.124973  2007.0    23.0  0.006417    16.0
# 51615       0.110619   0.109709  0.098270  2005.0     1.0  0.006417    16.0
# 167683      0.110619   0.109709  0.124973  2013.0    17.0  0.106949    16.0
# 111166      0.110619   0.109709  0.112954  2011.0     6.0  0.106949    16.0
# 58298       0.040273   0.045785  0.060903  2006.0     5.0  0.106949    24.0
#
#           ubigeo  edad  tipo_edad      sexo
# 63247   160108.0  11.0   0.072141  0.071239
# 51615   160101.0  41.0   0.072141  0.071239
# 167683  160108.0  16.0   0.072141  0.071239
# 111166  160113.0  43.0   0.072141  0.074113
# 58298   240101.0  14.0   0.072141  0.074113

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1

# %% [markdown]
# # Aplicando StandarScaler

# %%
from sklearn.preprocessing import StandardScaler

# Identify numerical columns (excluding the encoded categorical columns)
numerical_cols = X_train_encoded.select_dtypes(include=['float64', 'int64']).columns

# Initialize StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform all sets
X_train_scaled = scaler.fit_transform(X_train_encoded[numerical_cols])
X_test_scaled = scaler.transform(X_test_encoded[numerical_cols])
X_val_scaled = scaler.transform(X_val_encoded[numerical_cols])

# Convert the scaled arrays back to DataFrames for easier handling
X_train_scaled = pd.DataFrame(X_train_scaled, columns=numerical_cols, index=X_train_encoded.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=numerical_cols, index=X_test_encoded.index)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=numerical_cols, index=X_val_encoded.index)

# Display the first few rows of the scaled training set
print("First 5 rows of the scaled training set:")
display(X_train_scaled.head())
# Out:
# First 5 rows of the scaled training set:
#         departamento  provincia  distrito       ano    semana   tipo_dx  \
# 63247       0.708909   0.596907  0.800364 -0.163255  0.172844 -1.393140
# 51615       0.708909   0.596907  0.392217 -0.638520 -1.218242 -1.393140
# 167683      0.708909   0.596907  0.800364  1.262540 -0.206543  0.717803
# 111166      0.708909   0.596907  0.616658  0.787275 -0.902086  0.717803
# 58298      -0.608331  -0.436402 -0.178917 -0.400888 -0.965317  0.717803
#
#           diresa    ubigeo      edad  tipo_edad      sexo
# 63247  -0.694461 -0.162450 -0.932794  -0.097415 -1.063207
# 51615  -0.694461 -0.162575  0.790403  -0.097415 -1.063207
# 167683 -0.694461 -0.162450 -0.645595  -0.097415 -1.063207
# 111166 -0.694461 -0.162361  0.905283  -0.097415  0.940551
# 58298   0.243386  1.260508 -0.760475  -0.097415  0.940551

# %% [markdown]
# # Aplicando SMOTE

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# Display the new class distribution in the resampled training set
print("Class counts in y_train after SMOTE:")
display(y_train_resampled.value_counts())

print("\nNormalized class distribution in y_train after SMOTE:")
display(y_train_resampled.value_counts(normalize=True))
# Out:
# Class counts in y_train after SMOTE:
# diagnostic
# A97.0    97407
# A97.1    97407
# A97.2    97407
# Name: count, dtype: int64
# Normalized class distribution in y_train after SMOTE:
# diagnostic
# A97.0    0.333333
# A97.1    0.333333
# A97.2    0.333333
# Name: proportion, dtype: float64

# %% [markdown]
# # Verificando la aplicación

# %% [markdown]
# **Reasoning**:
# Print the value counts and normalized value counts of `y_train_resampled` to confirm the class distribution after SMOTE.

# %%
# Print the value counts of the resampled training set
print("Class counts in y_train_resampled after SMOTE:")
display(y_train_resampled.value_counts())

# Print the normalized value counts of the resampled training set
print("\nNormalized class distribution in y_train_resampled after SMOTE:")
display(y_train_resampled.value_counts(normalize=True))
# Out:
# Class counts in y_train_resampled after SMOTE:
# diagnostic
# A97.0    97407
# A97.1    97407
# A97.2    97407
# Name: count, dtype: int64
# Normalized class distribution in y_train_resampled after SMOTE:
# diagnostic
# A97.0    0.333333
# A97.1    0.333333
# A97.2    0.333333
# Name: proportion, dtype: float64

# %% [markdown]
# # Definición de los hiperparámetros  de MLP1

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the MLP model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_resampled.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(3, activation='softmax') # Output layer for 3 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,987 (39.01 KB)
#  Trainable params: 9,987 (39.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Entrenaminto

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variables
y_train_resampled_encoded = label_encoder.fit_transform(y_train_resampled)
y_test_encoded = label_encoder.transform(y_test)
y_val_encoded = label_encoder.transform(y_val)

# Train the model with encoded target variables
history = model.fit(X_train_resampled, y_train_resampled_encoded,
                    epochs=50,
                    batch_size=64,
                    validation_data=(X_val_scaled, y_val_encoded))
# Out:
# Epoch 1/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.6546 - loss: 0.7488 - val_accuracy: 0.6434 - val_loss: 0.6769
# Epoch 2/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7120 - loss: 0.6354 - val_accuracy: 0.6299 - val_loss: 0.6684
# Epoch 3/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.7367 - loss: 0.5916 - val_accuracy: 0.6453 - val_loss: 0.6471
# Epoch 4/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.7521 - loss: 0.5627 - val_accuracy: 0.6577 - val_loss: 0.6143
# Epoch 5/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.7614 - loss: 0.5454 - val_accuracy: 0.6613 - val_loss: 0.6096
# Epoch 6/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - accuracy: 0.7668 - loss: 0.5333 - val_accuracy: 0.6566 - val_loss: 0.6055
# Epoch 7/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7711 - loss: 0.5254 - val_accuracy: 0.6689 - val_loss: 0.5954
# Epoch 8/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7748 - loss: 0.5165 - val_accuracy: 0.6649 - val_loss: 0.5928
# Epoch 9/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7777 - loss: 0.5123 - val_accuracy: 0.6728 - val_loss: 0.6000
# Epoch 10/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7802 - loss: 0.5058 - val_accuracy: 0.6767 - val_loss: 0.5740
# Epoch 11/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7833 - loss: 0.4996 - val_accuracy: 0.6765 - val_loss: 0.5662
# Epoch 12/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.
50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.8049 - loss: 0.4560 - val_accuracy: 0.6788 - val_loss: 0.5844
# Epoch 44/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.8041 - loss: 0.4550 - val_accuracy: 0.6807 - val_loss: 0.5625
# Epoch 45/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.8054 - loss: 0.4557 - val_accuracy: 0.6796 - val_loss: 0.5725
# Epoch 46/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.8038 - loss: 0.4552 - val_accuracy: 0.6900 - val_loss: 0.5471
# Epoch 47/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.8044 - loss: 0.4561 - val_accuracy: 0.6839 - val_loss: 0.5679
# Epoch 48/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.8052 - loss: 0.4535 - val_accuracy: 0.6870 - val_loss: 0.5478
# Epoch 49/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.8063 - loss: 0.4524 - val_accuracy: 0.6850 - val_loss: 0.5504
# Epoch 50/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - accuracy: 0.8049 - loss: 0.4535 - val_accuracy: 0.6815 - val_loss: 0.5678

# %% [markdown]
# # Curva de apredizaje

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy with y-axis limit
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1) # Set y-axis limit from 0 to 1
plt.legend()
plt.show()

# Plot training and validation loss with y-axis limit
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 1) # Set y-axis limit from 0 to 1
plt.legend()
plt.show()

# %% [markdown]
# # Calculo del ROC-AUC para  prueba

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder

# One-hot encode the true test labels
ohe = OneHotEncoder(sparse_output=False)
y_test_one_hot = ohe.fit_transform(y_test_encoded.reshape(-1, 1))

# Iterate through each class and plot the ROC curve
n_classes = y_test_one_hot.shape[1]
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_one_hot[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Plot random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Each Class")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Definición de los hiperparámetros  de MLP2

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Set a random seed for reproducibility
tf.random.set_seed(42)

# Define the second MLP model with reduced neurons
model_2 = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_resampled.shape[1],)), # Reduced neurons
    Dropout(0.2),
    Dense(32, activation='relu'), # Reduced neurons
    Dropout(0.2),
    Dense(3, activation='softmax') # Output layer for 3 classes
])

# Compile the model
model_2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model_2.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,947 (11.51 KB)
#  Trainable params: 2,947 (11.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Entrenamiento de MLP2

# %%
# Train model_2 with the resampled training data and validation data
history_2 = model_2.fit(X_train_resampled, y_train_resampled_encoded,
                      epochs=50,
                      batch_size=64,
                      validation_data=(X_val_scaled, y_val_encoded))
# Out:
# Epoch 1/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - accuracy: 0.6368 - loss: 0.7801 - val_accuracy: 0.6149 - val_loss: 0.7129
# Epoch 2/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6951 - loss: 0.6733 - val_accuracy: 0.6378 - val_loss: 0.6465
# Epoch 3/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7091 - loss: 0.6435 - val_accuracy: 0.6310 - val_loss: 0.6483
# Epoch 4/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7184 - loss: 0.6228 - val_accuracy: 0.6345 - val_loss: 0.6381
# Epoch 5/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7251 - loss: 0.6093 - val_accuracy: 0.6387 - val_loss: 0.6299
# Epoch 6/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7307 - loss: 0.5982 - val_accuracy: 0.6500 - val_loss: 0.6240
# Epoch 7/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7353 - loss: 0.5894 - val_accuracy: 0.6457 - val_loss: 0.6253
# Epoch 8/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7394 - loss: 0.5838 - val_accuracy: 0.6491 - val_loss: 0.6186
# Epoch 9/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7419 - loss: 0.5787 - val_accuracy: 0.6594 - val_loss: 0.6034
# Epoch 10/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7451 - loss: 0.5747 - val_accuracy: 0.6498 - val_loss: 0.6126
# Epoch 11/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.
50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7615 - loss: 0.5401 - val_accuracy: 0.6662 - val_loss: 0.5787
# Epoch 43/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7620 - loss: 0.5410 - val_accuracy: 0.6649 - val_loss: 0.5873
# Epoch 44/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7627 - loss: 0.5410 - val_accuracy: 0.6691 - val_loss: 0.5740
# Epoch 45/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7628 - loss: 0.5413 - val_accuracy: 0.6655 - val_loss: 0.5823
# Epoch 46/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7625 - loss: 0.5396 - val_accuracy: 0.6661 - val_loss: 0.5816
# Epoch 47/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7634 - loss: 0.5385 - val_accuracy: 0.6677 - val_loss: 0.5837
# Epoch 48/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.7637 - loss: 0.5394 - val_accuracy: 0.6714 - val_loss: 0.5785
# Epoch 49/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.7629 - loss: 0.5389 - val_accuracy: 0.6714 - val_loss: 0.5787
# Epoch 50/50
# 4566/4566 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - accuracy: 0.7627 - loss: 0.5392 - val_accuracy: 0.6712 - val_loss: 0.5751

# %% [markdown]
# # Curva de aprendizaje

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy with y-axis limit for model_2
plt.plot(history_2.history['accuracy'], label='Training Accuracy')
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 2 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1) # Set y-axis limit from 0 to 1
plt.legend()
plt.show()

# Plot training and validation loss with y-axis limit for model_2
plt.plot(history_2.history['loss'], label='Training Loss')
plt.plot(history_2.history['val_loss'], label='Validation Loss')
plt.title('Model 2 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 1) # Set y-axis limit from 0 to 1
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the test set using model_2
y_pred_proba_2 = model_2.predict(X_test_scaled)
y_pred_2 = np.argmax(y_pred_proba_2, axis=1)

# Calculate and print the classification report for model_2
print("Classification Report for Model 2:")
print(classification_report(y_test_encoded, y_pred_2))

# Calculate and display the confusion matrix for model_2
print("\nConfusion Matrix for Model 2:")
conf_matrix_2 = confusion_matrix(y_test_encoded, y_pred_2)
display(conf_matrix_2)

# One-hot encode the true test labels (if not already done)
# Assuming y_test_encoded is already available from the previous model evaluation
ohe = OneHotEncoder(sparse_output=False)
y_test_one_hot = ohe.fit_transform(y_test_encoded.reshape(-1, 1))

# Plot the ROC curve for each class for model_2
n_classes = y_test_one_hot.shape[1]
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_one_hot[:, i], y_pred_proba_2[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Plot random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Each Class (Model 2)")
plt.legend(loc="lower right")
plt.show()

# Summarize results for model_2
print("\nOverall Summary of Model 2 Performance:")
print("""
The classification report indicates an overall accuracy of {accuracy:.2f} on the test set for Model 2.
Looking at individual classes:
- Class 0 (A97.0), the majority class, shows good precision, recall, and F1-score.
- Class 1 (A97.1) and Class 2 (A97.2), the minority classes, have lower precision, recall, and F1-scores compared to the majority class.

The confusion matrix shows the number of correct and incorrect predictions for each class.

The ROC curve and AUC values provide insights into Model 2's ability to distinguish between classes. Examine the generated ROC plot to compare the curves and AUC values for each class and see how Model 2 performs compared to the first model.
""".format(accuracy=accuracy)) # Note: Using 'accuracy' variable from the previous evaluation of model_2, if available.

# %% [markdown]
# **Reasoning**:
# Identify the categorical columns in the new training set (`X_train_m4`) by selecting columns with 'object' data type.
